# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/workspace/final_project_477
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/workspace/final_project_477

# %%
# !pip install matplotlib opencv-python plyfile scipy

# %%
# note: the configuration below only works with <= Python 3.9. If we are using Colab's Python 3.11+ by default, we'll have to get the newest version.
# !pip install 'trimesh>=2.35.39,<2.35.40' 'networkx>=2.2,<2.3'
# !pip install networkx trimesh
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.3/709.3 kB 11.6 MB/s eta 0:00:00
# ...

# %%
# some packages required but not mentioned in the readme
# !pip install ftfy
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/pointnet2-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.9 MB/s eta 0:00:00
# ...

# %%
# %cd third_party_pointnet2/pointnet2
# !python setup.py install
# Out:
# /content/drive/MyDrive/workspace/final_project_477/third_party_pointnet2/pointnet2
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
# ...

# %%
# !pip install cython
# %cd /content/drive/MyDrive/workspace/final_project_477/utils
# !python cython_compile.py build_ext --inplace
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/pointnet2-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
# /content/drive/MyDrive/workspace/final_project_477/utils
# running build_ext

# %%
# Don't run this cell!
# %cd /content/drive/MyDrive/workspace/final_project_477
# !bash data_download.sh

# %%
# DISABLE COMMENT AND RUN THIS CELL IF YOU HAVEN'T FINISHED SET UP!
# %cd /content/drive/MyDrive/workspace/final_project_477
# !mkdir -p Data/sunrgb_d
# !bash data_preparation.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# sunrgbd_trainval/label_v1/005336.txt
# sunrgbd_trainval/label_v1/005337.txt
# sunrgbd_trainval/label_v1/005338.txt
# sunrgbd_trainval/label_v1/005339.txt
# sunrgbd_trainval/label_v1/005340.txt
# sunrgbd_trainval/label_v1/005341.txt
# sunrgbd_trainval/label_v1/005342.txt
# sunrgbd_trainval/label_v1/005343.txt
# sunrgbd_trainval/label_v1/005344.txt
# sunrgbd_trainval/label_v1/005345.txt
# sunrgbd_trainval/label_v1/005346.txt
# sunrgbd_trainval/label_v1/005347.txt
# sunrgbd_trainval/label_v1/005348.txt
# sunrgbd_trainval/label_v1/005349.txt
# sunrgbd_trainval/label_v1/005350.txt
# sunrgbd_trainval/label_v1/005351.txt
# sunrgbd_trainval/label_v1/005352.txt
# sunrgbd_trainval/label_v1/005353.txt
# sunrgbd_trainval/label_v1/005354.txt
# sunrgbd_trainval/label_v1/005355.txt
# sunrgbd_trainval/label_v1/005356.txt
# sunrgbd_trainval/label_v1/005357.txt
# sunrgbd_trainval/label_v1/005358.txt
# sunrgbd_trainval/label_v1/005359.txt
# ...

# %%
# DISABLE COMMENT AND RUN THIS CELL IF YOU HAVEN'T FINISHED SET UP!
# %cd /content/drive/MyDrive/workspace/final_project_477
# !unzip -q outputs.zip -d .
# # we only care about sunrgbd
# !rm -rf outputs/*scannet*
# Out:
# /content/drive/MyDrive/workspace/final_project_477

# %%
# %cd /content/drive/MyDrive/workspace/final_project_477/
# !bash test_release_models.sh
# Out:
# /content/drive/MyDrive/workspace/final_project_477
# [I424 01:30:11.227758782 debug.cpp:50] [c10d] The debug level is set to DETAIL.
# Cannot import tensorboard. Will log to txt files only.
# Initializing Distributed Training. This is in BETA mode and hasn't been tested thoroughly. Use at your own risk :)
# To get the maximum speed-up consider reducing evaluations on val set by setting --eval_every_epoch to greater than 50
# ...
